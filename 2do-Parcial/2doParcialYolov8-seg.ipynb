# %%
# Instala ultralytics
# %pip install ultralytics
# Importa libreria ultralytics
import ultralytics
# Revisa y visualiza las capacidades computacionales del computador virtual
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.0/78.2 GB disk)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from ultralytics import settings

# Update a setting
settings.update({'runs_dir': '/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs'})

# %%
# !yolo task=detect mode=train model=yolov8n-seg.pt data= /content/dataset-29/data.yaml epochs=2 imgsz=640 plots=True save_period=1
# !yolo task=detect mode=train model=yolov8m-seg.pt data= /content/Quirpinchaca-7/data.yaml epochs=5 imgsz=640 plots=True save_period=1
# !yolo task=segment mode=train model=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/checkpoints/yolov8m-seg.pt data=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/data.yaml epochs=40 imgsz=640 plots=True save_period=1
# Out:
# ...
# 100% 52.4M/52.4M [00:00<00:00, 186MB/s]
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train
# Out:
# args.yaml					    MaskF1_curve.png	 train_batch1.jpg
# BoxF1_curve.png					    MaskP_curve.png	 train_batch2.jpg
# BoxP_curve.png					    MaskPR_curve.png	 val_batch0_labels.jpg
# BoxPR_curve.png					    MaskR_curve.png	 val_batch0_pred.jpg
# BoxR_curve.png					    results.csv		 val_batch1_labels.jpg
# confusion_matrix_normalized.png			    results.png		 val_batch1_pred.jpg
# confusion_matrix.png				    train_batch0.jpg	 val_batch2_labels.jpg
# events.out.tfevents.1699621793.09a0eec0a933.4434.0  train_batch1770.jpg  val_batch2_pred.jpg
# labels_correlogram.jpg				    train_batch1771.jpg  weights
# labels.jpg					    train_batch1772.jpg

# %%
Image(filename='/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train/confusion_matrix.png', width=600)

# %%
Image(filename='/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train/results.png', width=800)

# %%
Image(filename='/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=segment mode=val model=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train/weights/best.pt data=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/data.yaml
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
# val: Scanning /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/valid/labels.cache... 266 images, 0 backgrounds, 0 corrupt: 100% 266/266 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP50  mAP50-95): 100% 17/17 [00:11<00:00,  1.42it/s]
#                    all        266        296      0.851      0.805      0.874      0.696       0.86      0.814      0.885       0.65
#                 hierro        266        104      0.841      0.713      0.853      0.631      0.841      0.714      0.857      0.497
#               letreros        266         82      0.803      0.829      0.857      0.695      0.802      0.829      0.857      0.676
# ...

# %%
# !yolo task=segment mode=predict model=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/test/images save=true
# Out:
# Ultralytics YOLOv8.0.208 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8m-seg summary (fused): 245 layers, 27224121 parameters, 0 gradients, 110.0 GFLOPs
#
# image 1/133 /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/test/images/letrero-publicidad101_jpg.rf.37be3875fccacabe9be9eb5a8e79f876.jpg: 640x640 1 letreros, 45.7ms
# image 2/133 /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/test/images/letrero-publicidad108_jpg.rf.8d46093ffb190932a74af8a9e4e36369.jpg: 640x640 1 letreros, 55.1ms
# image 3/133 /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/test/images/letrero-publicidad110_jpg.rf.1a185c9806943e010e1e827d841c5fa2.jpg: 640x640 2 letreross, 46.7ms
# image 4/133 /content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/2doParcial.v1i.yolov8/test/images/letrero-publicidad118_jpg.rf.c274e6f6f3b4c8989d80b9c1e2443abe.jpg: 640x640 1 letreros, 46.0ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob('/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
import glob
from IPython.display import Image, display

# Obtén la lista de rutas de las imágenes
imagen_rutas = glob.glob('/content/drive/MyDrive/IA2-2-2023/2do-Parcial/dataset/runs/segment/predict/*.jpg')

# Itera sobre cada 30 imágenes y muestra las primeras 6
for i in range(0, len(imagen_rutas), 30):
    for j in range(6):
        idx = i + j
        if idx < len(imagen_rutas):
            image_path = imagen_rutas[idx]
            display(Image(filename=image_path, width=600))
            print("\n")
# Out:
# Output hidden; open in https://colab.research.google.com to view.
